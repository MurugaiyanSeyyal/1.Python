# %%
from multipleFunctions import allFunctions

# %%
af = allFunctions()

# %%
af.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
af.OddEven()
# Out:
# Enter the Number:  52452
# 52452 is Even Number

# %%
gender = input("Your Gender: ")
age = int(input("Your Age: "))
print(af.Elegible(gender, age))
# Out:
# Your Gender:  Male
# Your Age:  20
# Not Elegible

# %%
Subjects1 = int(input("Subjects-1 = "))
Subjects2 = int(input("Subjects-2 = "))
Subjects3 = int(input("Subjects-3 = "))
Subjects4 = int(input("Subjects-4 = "))
Subjects5 = int(input("Subjects-5 = "))

total, per = af.percentage(Subjects1, Subjects2, Subjects3, Subjects4, Subjects5)
print("Total :", total)
print("Percentage :", per)
# Out:
# Subjects-1 =  98
# Subjects-2 =  87
# Subjects-3 =  95
# Subjects-4 =  95
# Subjects-5 =  93
# Total : 468
# Percentage : 93.6

# %%
height = int(input("Height: "))
breadth = int(input("Breadth: "))
print("Area formula: (Height*Breadth) / 2")
print("Area of Triangle: ", area)

height1 = int(input("Height1: "))
height2 = int(input("Height2: "))
breadth2 = int(input("Breadth2: "))
print("Perimeter formula: Height1 + Height2 + Breadth2")

area, perimeter = af.triangle(height, breadth, height1, height2, breadth2)

print("Perimeter of Triangle: ", perimeter)
# Out:
# Height:  32
# Breadth:  34
# Area formula: (Height*Breadth) / 2
# Area of Triangle:  544.0
# Height1:  2
# Height2:  4
# Breadth2:  4
# Perimeter formula: Height1 + Height2 + Breadth2
# Perimeter of Triangle:  10
