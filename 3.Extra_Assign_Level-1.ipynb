# %%
# Print Statement

print("Hope AI")
# Out:
# Hope AI

# %%
# Buy Input

name = input("Enter Your Name: ")
age = int(input("Enter Your Age: "))
school = input("Enter Your School Name: ")
degree = input("Enter Your Degree: ")
# Out:
# Enter Your Name:  Murugaiyan
# Enter Your Age:  38
# Enter Your School Name:  VOC
# Enter Your Degree:  MCA

# %%
# Addition

a=int(input("Input Value A: "))
b=int(input("Input Value B: "))
add=a+b
print("A: ",a)
print("B: ",b)
print("Add:",add)
# Out:
# Input Value A:  43
# Input Value B:  34
# A:  43
# B:  34
# Add: 77

# %%
# Subtraction

a = int(input("Input Value A: "))
b = int(input("Input Value B: "))
sub = a-b
print("A: ",a)
print("B: ",b)
print("Sub: ",sub)
# Out:
# Input Value A:  43
# Input Value B:  34
# A:  43
# B:  34
# Sub:  9

# %%
# Multiplication

a = int(input("Input Value A: "))
b = int(input("Input Value B: "))
mul = a*b
print("A: ",a)
print("B: ",b)
print("Mul: ",mul)
# Out:
# Input Value A:  63
# Input Value B:  97
# A:  63
# B:  97
# Mul:  6111

# %%
# Division

a = int(input("Input Value A: "))
b = int(input("Input Value B: "))
div = a/b
print("A: ",a)
print("B: ",b)
print("Float Div: ",div)
# Out:
# Input Value A:  76
# Input Value B:  31
# A:  76
# B:  31
# Float Div:  2.4516129032258065

# %%
# Floor Division

a = int(input("Input Value A: "))
b = int(input("Input Value B: "))
div_f = a // b
print("A: ",a)
print("B: ",b)
print("Floor Div: ",div_f)
# Out:
# Input Value A:  76
# Input Value B:  31
# A:  76
# B:  31
# Floor Div:  2

# %%
# Modulo

a = int(input("Input Value A: "))
b = int(input("Input Value B: "))
modulo = a % b
print("A: ",a)
print("B: ",b)
print("Modulo: ",modulo)
# Out:
# Input Value A:  76
# Input Value B:  31
# A:  76
# B:  31
# Modulo:  14

# %%
# Power

a = int(input("Input Value A: "))
b = int(input("Input Value B: "))
power = a ** b
print("A: ",a)
print("B: ",b)
print("Power: ",power)
# Out:
# Input Value A:  4
# Input Value B:  4
# A:  4
# B:  4
# Power:  256
